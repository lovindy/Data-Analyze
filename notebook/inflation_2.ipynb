# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Sample data
data = {
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'CPI': [172.2, 177.1, 179.9, 184.0, 188.9, 195.3, 201.6, 207.3, 215.3, 214.5, 218.1, 224.9, 229.6, 233.0, 236.7, 237.0, 240.0, 245.1, 251.1, 255.7, 258.8, 271.0, 283.2]
}

df = pd.DataFrame(data)

# Set 'Year' as index
df.set_index('Year', inplace=True)

# %%
df
# Out:
#         CPI
# Year
# 2000  172.2
# 2001  177.1
# 2002  179.9
# 2003  184.0
# 2004  188.9
# 2005  195.3
# 2006  201.6
# 2007  207.3
# 2008  215.3
# 2009  214.5
# 2010  218.1
# 2011  224.9
# 2012  229.6
# 2013  233.0
# 2014  236.7
# 2015  237.0
# 2016  240.0
# 2017  245.1
# 2018  251.1
# 2019  255.7
# 2020  258.8
# 2021  271.0
# 2022  283.2
